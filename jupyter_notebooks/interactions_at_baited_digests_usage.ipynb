# %%
import sys
import os
import pandas
import copy
sys.path.append("..")
from diachr import DiachromaticInteractionSet
from diachr import BaitedDigest
from diachr import BaitedDigestSet

# %% [markdown]
# # Interactions at baited digests - Usage

# %% [markdown]
# In this Jupyter notebook, the classes ``BaitedDigest`` and ``BaitedDigestSet`` are demonstrated.
#
# The class ``BaitedDigest`` can be used to group interactions according to the baits. For each bait, interactions are further differntiated according to interaction category (``DIX``, ``DI``, ``UIR``, ``UI`` and ``ALL``) and enrichment status (``NE`` or ``EN``). Interactions with the enrichment state `NN` or ``EE`` cannot be assigned unabgiuously to a baited digests and, therefore, are not taken into account. However, for capture Hi-C data, such interactions make up only a small percentage (around 15% on average).
#
# The class ``BaitedDigestSet`` can be used to manage a set of ``BaitedDigest`` objects. It is basically a dictionary in which ``BaitedDigest`` objects are stored, with the coordinates of the digests serving as keys.
#
# This structuring of the data allows to investigate interactions at individual baits.

# %% [markdown]
# ## Input file for testing
#
# We have prepared two small test files in ``Diachromatic11`` format.

# %%
# Interactions on 'chr21' and 'chr22' only
INTERACTION_FILE = "../tests/data/baited_digests_d11_interaction_test_file.tsv.gz"
OUT_PREFIX = "TEST_FILE_1"

# 100,000 randomly selected interactions
#INTERACTION_FILE = "../tests/data/baited_digests_d11_interaction_test_file_2.tsv.gz"
#OUT_PREFIX = "TEST_FILE_2"

# %% [markdown]
# ## Creation of a ``BaitedDigestSet``
#
# First, we create a ``DiachromaticInteractionSet`` from the test file.

# %%
# Create DiachromaticInteractionSet
d11_interaction_set = DiachromaticInteractionSet(rpc_rule = 'ht')
d11_interaction_set.parse_file(
    i_file = INTERACTION_FILE,
    verbose = True)
# Out:
# [INFO] Parsing Diachromatic interaction file ...
# 	[INFO] ../tests/data/baited_digests_d11_interaction_test_file.tsv.gz
# 	[INFO] Set size: 118,468
# [INFO] ... done.

# %% [markdown]
# Next, we create a ``BaitedDigestSet`` and pass the ``DiachromaticInteractionSet``.

# %%
baited_digest_set = BaitedDigestSet()
read_interactions_info_dict = baited_digest_set.ingest_interaction_set(d11_interaction_set, verbose=True)
# Out:
# [INFO] Reading interactions and group them according to chromosomes and baited digests ...
# 	[INFO] Total number of interactions read: 118,468
# 	[INFO] Total number of baited digests: 680
# [INFO] ... done.

# %% [markdown]
# The function ``get_ingest_interaction_set_info_report()`` returns a string with more detailed information on the ingestion.

# %%
print(baited_digest_set.get_ingest_interaction_set_info_report())
# Out:
# [INFO] Report on ingestion of interactions:
# 	[INFO] Total number of interactions read: 118,468
# 	[INFO] Discarded NN and EE interactions: 11,996
# 	[INFO] Total number of ingested NE and EN interactions: 106,472
# 	[INFO] Broken down by interaction category and enrichment status:
# 		[INFO] DIX:
# 			[INFO] NE: 1
# 			[INFO] EN: 0
# 		[INFO] DI:
# 			[INFO] NE: 2,501
# 			[INFO] EN: 2,559
# 		[INFO] UIR:
# 			[INFO] NE: 2,257
# 			[INFO] EN: 1,825
# 		[INFO] UI:
# 			[INFO] NE: 46,851
# 			[INFO] EN: 50,478
# 		[INFO] ALL:
# 			[INFO] NE: 51,610
# 			[INFO] EN: 54,862
# 	[INFO] Total number of baited digests: 680
# [INFO] End of report.

# %% [markdown]
# And the function ``get_ingest_interaction_set_table_row()`` returns the same information in table format.

# %%
print(baited_digest_set.get_ingest_interaction_set_table_row())
# Out:
# :TR_INGESTION:	TOTAL_INTERACTIONS_READ	DISCARDED	INGESTED	DIX_NE	DIX_EN	DI_NE	DI_EN	UIR_NE	UIR_EN	UI_NE	UI_EN	ALL_NE	ALL_EN	BAITED_DIGESTS
# :TR_INGESTION:	118468	11996	106472	1	0	2501	2559	2257	1825	46851	50478	51610	54862	680

# %% [markdown]
# ## Explanation of the data structure
#
# In the object ``baited_digest_set``, the chromosomes are first grouped according to chromosomes. For example, ``baited_digest_set._baited_digest_dict['chr21']`` all ``BaitedDigest`` object that were created for ``chr21``.

# %%
dict_all_baited_digest_objects_on_chr21 = baited_digest_set._baited_digest_dict['chr21']

# %% [markdown]
# A individual ``BaitedDigest`` object can be accessed via its digest coordinates.

# %%
individual_baited_digest_object_on_chr21 = baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012']

# %% [markdown]
# An ``BaitedDigest``, contains all interactions that end in this digest, spearted by interaction category and enrichment state. Here, as an example, an interaction of category ``DI`` with enricchment state ``NE``.

# %%
baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012'].interactions['DI']['NE'][0].get_category()
# Out:
# 'DI'

# %%
baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012'].interactions['DI']['NE'][0].enrichment_status_tag_pair
# Out:
# 'NE'

# %%
baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012'].interactions['DI']['NE'][0].fromB
# Out:
# 33167499

# %%
baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012'].interactions['DI']['NE'][0].toB
# Out:
# 33175012

# %%
baited_digest_set._baited_digest_dict['chr21']['chr21\t33167499\t33175012'].interactions['DI']['NE'][0].rp_total
# Out:
# 125

# %% [markdown]
# ## Iterate baited digest set
#
# The data structure allows to iterate over all baited digests and associated interactions. In this example, for each bait, the numbers of interactions that go from the bait to the left or right are determined.

# %%
di_baited_digests = 0
di_num_total = 0
for chrom in baited_digest_set._baited_digest_dict.keys():
    for baited_digest_key, baited_digest in baited_digest_set._baited_digest_dict[chrom].items():
        dix_num_ne = len(baited_digest.interactions['DIX']['NE'])
        dix_num_en = len(baited_digest.interactions['DIX']['EN'])
        di_num_ne = len(baited_digest.interactions['DI']['NE'])
        di_num_en = len(baited_digest.interactions['DI']['EN'])
        uir_num_ne = len(baited_digest.interactions['UIR']['NE'])
        uir_num_en = len(baited_digest.interactions['UIR']['EN'])
        ui_num_ne = len(baited_digest.interactions['UI']['NE'])
        ui_num_en = len(baited_digest.interactions['UI']['EN'])
        all_num_ne = len(baited_digest.interactions['ALL']['NE'])
        all_num_en = len(baited_digest.interactions['ALL']['EN'])
                
        print('-----------')
        print('Key: ' + baited_digest_key)
        print('Unbalanced without reference: '  + str(dix_num_ne) + ', ' + str(dix_num_en))
        print('Unbalanced: '  + str(di_num_ne) + ', ' + str(di_num_en))
        print('Balanced reference: '  + str(uir_num_ne) + ', ' + str(uir_num_en))
        print('Balanced: '  + str(ui_num_ne) + ', ' + str(ui_num_en))
        print('All: '  + str(all_num_ne) + ', ' + str(all_num_en))
# Out:
# -----------
# Key: chr21	35717316	35721211
# Unbalanced without reference: 0, 0
# Unbalanced: 9, 6
# Balanced reference: 12, 67
# Balanced: 308, 29
# All: 329, 102
# -----------
# Key: chr21	41739289	41741963
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 5
# Balanced reference: 2, 21
# Balanced: 89, 74
# All: 99, 100
# -----------
# Key: chr21	16031845	16036421
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 0, 7
# Balanced: 79, 205
# All: 80, 215
# -----------
# Key: chr21	30209798	30216814
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 1, 35
# Balanced: 88, 74
# All: 89, 110
# -----------
# Key: chr21	34667825	34671202
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 27
# Balanced: 63, 78
# All: 63, 105
# -----------
# Key: chr21	45234082	45236451
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 8, 0
# Balanced: 97, 132
# All: 105, 132
# -----------
# Key: chr21	25937466	25943895
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 5, 0
# Balanced: 57, 152
# All: 62, 152
# -----------
# Key: chr21	43656918	43662054
# Unbalanced without reference: 0, 0
# Unbalanced: 15, 14
# Balanced reference: 7, 0
# Balanced: 61, 46
# All: 83, 60
# -----------
# Key: chr21	26188036	26195882
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 7, 0
# Balanced: 204, 298
# All: 212, 300
# -----------
# Key: chr21	20995103	20999338
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 51
# Balanced: 140, 495
# All: 141, 547
# -----------
# Key: chr21	33489173	33496130
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 6, 0
# Balanced: 166, 107
# All: 173, 107
# -----------
# Key: chr21	32304687	32315763
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 2, 38
# Balanced: 149, 51
# All: 151, 89
# -----------
# Key: chr21	25639067	25641449
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 7, 0
# Balanced: 122, 255
# All: 129, 258
# -----------
# Key: chr21	42008931	42015587
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 1, 41
# Balanced: 71, 45
# All: 75, 88
# -----------
# Key: chr21	36982585	36992923
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 4
# Balanced reference: 13, 0
# Balanced: 153, 149
# All: 169, 153
# -----------
# Key: chr21	30736306	30747469
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 5, 85
# Balanced: 140, 27
# All: 145, 112
# -----------
# Key: chr21	45401689	45423170
# Unbalanced without reference: 1, 0
# Unbalanced: 6, 6
# Balanced reference: 1, 4
# Balanced: 65, 68
# All: 73, 78
# -----------
# Key: chr21	45638887	45647279
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 13
# Balanced reference: 5, 0
# Balanced: 124, 82
# All: 133, 95
# -----------
# Key: chr21	35983609	35987950
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 29, 37
# Balanced: 443, 83
# All: 472, 120
# -----------
# Key: chr21	29936795	29940477
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 3, 7
# Balanced: 172, 117
# All: 176, 125
# -----------
# Key: chr21	31654960	31666852
# Unbalanced without reference: 0, 0
# Unbalanced: 18, 20
# Balanced reference: 6, 0
# Balanced: 106, 107
# All: 130, 127
# -----------
# Key: chr21	15708190	15709418
# Unbalanced without reference: 0, 0
# Unbalanced: 2,
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 8, 0
# Balanced: 166, 172
# All: 174, 173
# -----------
# Key: chr21	31554239	31561093
# Unbalanced without reference: 0, 0
# Unbalanced: 14, 2
# Balanced reference: 16, 4
# Balanced: 115, 91
# All: 145, 97
# -----------
# Key: chr21	32406509	32415128
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 4
# Balanced reference: 6, 0
# Balanced: 53, 80
# All: 60, 84
# -----------
# Key: chr21	17435882	17450320
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 16
# Balanced reference: 5, 0
# Balanced: 3, 73
# All: 14, 89
# -----------
# Key: chr21	28875459	28885742
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 0, 4
# Balanced: 77, 41
# All: 80, 47
# -----------
# Key: chr21	37915149	37921355
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 10, 0
# Balanced: 88, 180
# All: 99, 181
# -----------
# Key: chr21	42187817	42208913
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 2, 0
# Balanced: 51, 56
# All: 54, 57
# -----------
# Key: chr21	33066978	33071924
# Unbalanced without reference: 0, 0
# Unbalanced: 9, 1
# Balanced reference: 4, 0
# Balanced: 88, 95
# All: 101, 96
# -----------
# Key: chr21	43860361	43866224
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 8
# Balanced reference: 2, 18
# Balanced: 38, 19
# All: 43, 45
# -----------
# Key: chr21	17886374	17903656
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 0
# Balanced reference: 3, 3
# Balanced: 98, 25
# All: 104, 28
# -----------
# Key: chr21	39181139	39185263
# Unbalanced without reference: 0, 0
# Unbalanced: 14, 18
# Balanced reference: 7, 0
# Balanced: 214, 43
# All: 235, 61
# -----------
# Key: chr21	32376472	32380619
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 21
# Balanced reference: 8, 0
# Balanced: 88, 76
# All: 106, 97
# -----------
# Key: chr21	15684751	15696365
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 8, 0
# Balanced: 255, 60
# All: 263, 60
# -----------
# Key: chr21	43986918	44000009
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 2, 0
# Balanced: 17, 9
# All: 19, 9
# -----------
# Key: chr21	46219644	46230758
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 1, 14
# Balanced: 38, 62
# All: 40, 78
# -----------
# Key: chr21	16282745	16285812
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 11, 0
# Balanced: 138, 131
# All: 151, 131
# -----------
# Key: chr21	41533591	41541341
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 3
# Balanced reference: 6, 0
# Balanced: 70, 56
# All: 86, 59
# -----------
# Key: chr21	42395654	42397107
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 6, 0
# Balanced: 115, 77
# All: 122, 77
# -----------
# Key: chr21	39864333	39869024
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 4
# Balanced reference: 3, 0
# Balanced: 88, 146
# All: 93, 150
# -----------
# Key: chr21	36064042	36073196
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 11
# Balanced reference: 6, 0
# Balanced: 177, 45
# All: 187, 56
# -----------
# Key: chr21	32812795	32814689
# Unbalanced without reference: 0, 0
# Unbalanced: 17, 28
# Balanced reference: 0, 3
# Balanced: 48, 115
# All: 65, 146
# -----------
# Key: chr21	38655394	38668113
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 6, 0
# Balanced: 150, 138
# All: 157, 138
# -----------
# Key: chr21	15612563	15617133
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 8
# Balanced reference: 8, 0
# Balanced: 197, 69
# All: 212, 77
# -----------
# Key: chr21	18782489	18791793
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 8
# Balanced reference: 3, 0
# Balanced: 53, 82
# All: 63, 90
# -----------
# Key: chr21	15046775	15057854
# Unbalanced without reference: 0, 0
# Unbalanced: 18, 16
# Balanced reference: 5, 0
# Balanced: 146, 144
# All: 169, 160
# -----------
# Key: chr21	25338367	25341460
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 16, 0
# Balanced: 360, 168
# All: 376, 169
# -----------
# Key: chr21	26157930	26164360
# Unbalanced without reference: 0, 0
# Unbalanced: 19, 9
# Balanced reference: 2, 0
# Balanced: 131, 136
# All: 152, 145
# -----------
# Key: chr21	16713345	16719104
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 4, 0
# Balanced: 113, 142
# All: 117, 142
# -----------
# Key: chr21	14654593	14663249
# Unbalanced without reference: 0, 0
# Unbalanced: 11, 5
# Balanced reference: 4, 0
# Balanced: 66, 120
# All: 81, 125
# -----------
# Key: chr21	25730027	25736490
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 2
# Balanced reference: 8, 12
# Balanced: 122, 257
# All: 137, 271
# -----------
# Key: chr21	32383077	32394854
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 10
# Balanced reference: 11, 1
# Balanced: 112, 100
# All: 123, 111
# -----------
# Key: chr21	46634856	46636356
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 7, 0
# Balanced: 77, 6
# All: 84, 6
# -----------
# Key: chr21	43716753	43735443
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 0
# Balanced reference: 8, 0
# Balanced: 58, 45
# All: 73, 45
# -----------
# Key: chr21	45826431	45839424
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 6
# Balanced reference: 17, 0
# Balanced: 194, 49
# All: 212, 55
# -----------
# Key: chr21	30282251	30284607
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 1
# Balanced reference: 14, 0
# Balanced: 97, 203
# All: 113, 204
# -----------
# Key: chr21	30634718	30635665
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 2
# Balanced reference: 5, 0
# Balanced: 113, 125
# All: 118, 127
# -----------
# Key: chr21	15728990	15733873
# Unbalanced without reference: 0, 0
# Unbalanced: 38, 9
# Balanced reference: 9, 0
# Balanced: 292, 63
# All: 339, 72
# -----------
# Key: chr21	32530222	32539917
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 4, 0
# Balanced: 121, 60
# All: 126, 62
# -----------
# Key: chr21	17450321	17455847
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 11, 1
# Balanced: 53, 145
# All: 65, 149
# -----------
# Key: chr21	42403422	42404246
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 5, 0
# Balanced: 80, 62
# All: 86, 64
# -----------
# Key: chr21	30635666	30645934
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 3, 0
# Balanced: 48, 58
# All: 52, 59
# -----------
# Key: chr21	36073713	36080679
# Unbalanced without reference: 0, 0
# Unbalanced: 13, 11
# Balanced reference: 6, 0
# Balanced: 229, 49
# All: 248, 60
# -----------
# Key: chr21	14214918	14227459
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 1
# Balanced: 27, 197
# All: 27, 199
# -----------
# Key: chr21	46601955	46611668
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 6
# Balanced reference: 6, 0
# Balanced: 63, 8
# All: 79, 14
# -----------
# Key: chr21	40512059	40527400
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 10, 0
# Balanced: 66, 121
# All: 76, 121
# -----------
# Key: chr21	32091403	32096331
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 3
# Balanced reference: 10, 1
# Balanced: 197, 76
# All: 210, 80
# -----------
# Key: chr21	30752472	30760286
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference:
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 2, 0
# Balanced: 11, 50
# All: 14, 52
# -----------
# Key: chr21	26377510	26379608
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 7
# Balanced reference: 4, 0
# Balanced: 80, 102
# All: 90, 109
# -----------
# Key: chr21	30479557	30486991
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 5
# Balanced reference: 0, 24
# Balanced: 54, 60
# All: 62, 89
# -----------
# Key: chr21	36316532	36344102
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 8
# Balanced reference: 1, 0
# Balanced: 28, 35
# All: 37, 43
# -----------
# Key: chr21	30284608	30291147
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 7, 0
# Balanced: 80, 176
# All: 88, 178
# -----------
# Key: chr21	41952289	41961240
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 9
# Balanced reference: 2, 0
# Balanced: 79, 99
# All: 82, 108
# -----------
# Key: chr21	45377611	45401688
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 2, 0
# Balanced: 84, 91
# All: 87, 92
# -----------
# Key: chr21	30393990	30403177
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 1, 0
# Balanced: 79, 153
# All: 80, 154
# -----------
# Key: chr21	26962790	26969288
# Unbalanced without reference: 0, 0
# Unbalanced: 16, 9
# Balanced reference: 2, 0
# Balanced: 123, 301
# All: 141, 310
# -----------
# Key: chr21	29059206	29063075
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 6
# Balanced reference: 2, 1
# Balanced: 25, 137
# All: 34, 144
# -----------
# Key: chr21	26388279	26394107
# Unbalanced without reference: 0, 0
# Unbalanced: 15, 14
# Balanced reference: 5, 0
# Balanced: 112, 99
# All: 132, 113
# -----------
# Key: chr21	19345114	19346842
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 2, 0
# Balanced: 78, 95
# All: 81, 95
# -----------
# Key: chr21	20349320	20357124
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 10, 0
# Balanced: 283, 151
# All: 294, 152
# -----------
# Key: chr21	42358987	42384257
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 3
# Balanced reference: 1, 0
# Balanced: 27, 26
# All: 30, 29
# -----------
# Key: chr21	39443554	39446872
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 2
# Balanced reference: 6, 0
# Balanced: 67, 83
# All: 78, 85
# -----------
# Key: chr21	43811765	43818170
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 12
# Balanced reference: 0, 0
# Balanced: 33, 38
# All: 36, 50
# -----------
# Key: chr21	32838896	32854974
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 25
# Balanced reference: 0, 41
# Balanced: 42, 41
# All: 47, 107
# -----------
# Key: chr21	41766292	41768422
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 1, 13
# Balanced: 107, 97
# All: 109, 110
# -----------
# Key: chr21	39318106	39323143
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 1
# Balanced reference: 0, 0
# Balanced: 144, 69
# All: 147, 70
# -----------
# Key: chr21	41337983	41367583
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 2
# Balanced reference: 1, 0
# Balanced: 35, 76
# All: 38, 78
# -----------
# Key: chr21	16537706	16540171
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 2, 0
# Balanced: 130, 127
# All: 132, 127
# -----------
# Key: chr21	40379995	40385730
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 1, 0
# Balanced: 96, 122
# All: 98, 122
# -----------
# Key: chr21	30486992	30489312
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 7
# Balanced reference: 0, 25
# Balanced: 99, 118
# All: 106, 150
# -----------
# Key: chr21	30312806	30323879
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 3
# Balanced reference: 2, 0
# Balanced: 35, 59
# All: 40, 62
# -----------
# Key: chr21	30334243	30344938
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 8
# Balanced reference: 2, 0
# Balanced: 57, 95
# All: 62, 103
# -----------
# Key: chr21	34362186	34378925
# Unbalanced without reference: 0, 0
# Unbalanced: 11, 9
# Balanced reference: 0, 0
# Balanced: 117, 58
# All: 128, 67
# -----------
# Key: chr21	42559167	42563706
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 5
# Balanced reference: 3, 21
# Balanced: 127, 70
# All: 136, 96
# -----------
# Key: chr21	25431687	25433103
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 4, 0
# Balanced: 90, 232
# All: 94, 235
# -----------
# Key: chr21	34063670	34074276
# Unbalanced without reference: 0, 0
# Unbalanced: 20, 20
# Balanced reference: 1, 0
# Balanced: 72, 106
# All: 93, 126
# -----------
# Key: chr21	44653525	44658836
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 13
# Balanced: 33, 70
# All: 34, 84
# -----------
# Key: chr21	23280505	23286421
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 89, 119
# All: 90, 119
# -----------
# Key: chr21	33903887	33912711
# Unbalanced without reference: 0, 0
# Unbalanced: 20, 9
# Balanced reference: 2, 1
# Balanced: 66, 125
# All: 88, 135
# -----------
# Key: chr21	36253740	36260962
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 6
# Balanced reference: 0, 16
# Balanced: 68, 90
# All: 76, 112
# -----------
# Key: chr21	33914457	33917455
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 1
# Balanced reference: 1, 0
# Balanced: 67, 126
# All: 70, 127
# -----------
# Key: chr21	44678452	44690833
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 11
# Balanced reference: 1, 1
# Balanced: 30, 86
# All: 41, 98
# -----------
# Key: chr21	43912498	43920070
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 5, 0
# Balanced: 37, 35
# All: 42, 35
# -----------
# Key: chr21	32584985	32599255
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 2, 12
# Balanced: 93, 39
# All: 96, 51
# -----------
# Key: chr21	29071972	29082408
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 6
# Balanced reference: 0, 0
# Balanced: 33, 188
# All: 33, 194
# -----------
# Key: chr21	44898678	44936305
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 12, 8
# All: 13, 8
# -----------
# Key: chr21	42107387	42122267
# Unbalanced without reference: 0, 0
# Unbalanced: 12, 0
# Balanced reference: 3, 0
# Balanced: 73, 72
# All: 88, 72
# -----------
# Key: chr21	16589727	16591860
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 9
# Balanced: 50, 31
# All: 50, 40
# -----------
# Key: chr21	41417409	41425022
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 4
# Balanced reference: 0, 0
# Balanced: 30, 60
# All: 40, 64
# -----------
# Key: chr21	22204965	22209045
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 0, 0
# Balanced: 25, 17
# All: 27, 17
# -----------
# Key: chr21	39556288	39558017
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 5
# Balanced reference: 0, 0
# Balanced: 42, 195
# All: 46, 200
# -----------
# Key: chr21	46153624	46168759
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 5
# Balanced reference: 1, 0
# Balanced: 47, 58
# All: 49, 63
# -----------
# Key: chr21	33319565	33325889
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 0, 0
# Balanced: 24, 29
# All: 24, 32
# -----------
# Key: chr21	14580091	14582294
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 12, 1
# Balanced: 67, 333
# All: 79, 334
# -----------
# Key: chr21	41528647	41533504
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 2, 0
# Balanced: 31, 23
# All: 35, 23
# -----------
# Key: chr21	14582295	14585365
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 13, 0
# Balanced: 63, 328
# All: 77, 329
# -----------
# Key: chr21	33629825	33644115
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 25
# Balanced reference: 0, 38
# Balanced: 26, 48
# All: 28, 111
# -----------
# Key: chr21	25465606	25470328
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 6
# Balanced reference: 0, 0
# Balanced: 23, 46
# All: 26, 52
# -----------
# Key: chr21	43774112	43779729
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 3
# Balanced reference: 0, 0
# Balanced: 29, 30
# All: 33, 33
# -----------
# Key: chr21	32609375	32615433
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 2
# Balanced reference: 0, 0
# Balanced: 49, 41
# All: 53, 43
# -----------
# Key: chr21	33378357	33389430
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 5
# Balanced reference: 0, 5
# Balanced: 50, 14
# All: 58, 24
# -----------
# Key: chr21	44556915	44561619
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 7
# Balanced reference: 0, 0
# Balanced: 15, 42
# All: 19, 49
# -----------
# Key: chr21	46283640	46292406
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 2
# Balanced reference: 1, 0
# Balanced: 6, 46
# All: 11, 48
# -----------
# Key: chr21	44797276	44803934
# Unbalanced without reference: 0, 0
# Unbalanced: 12, 10
# Balanced reference: 1, 0
# Balanced: 59, 86
# All: 72, 96
# -----------
# Key: chr21	30493703	30500222
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 5
# Balanced reference: 0, 7
# Balanced: 77, 108
# All: 80, 120
# -----------
# Key: chr21	36445539	36446180
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 7
# Balanced reference: 0, 0
# Balanced: 30, 146
# All: 30, 153
# -----------
# Key: chr21	44807647	44822197
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 2
# Balanced reference: 0, 0
# Balanced: 71, 82
# All: 71, 84
# -----------
# Key: chr21	32021567	32025593
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 30, 30
# All: 30, 30
# -----------
# Key: chr21	46323276	46338460
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 1, 0
# Balanced: 16, 74
# All: 18, 74
# -----------
# Key: chr21	29176986	29185161
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 67
# Balanced: 31, 31
# All: 31, 99
# -----------
# Key: chr21	44573213	44577432
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 19, 41
# All: 20, 41
# -----------
# Key: chr21	44869910	44876475
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 4
# Balanced reference: 0, 0
# Balanced: 48, 51
# All: 56, 55
# -----------
# Key: chr21	30489313	30493392
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 0, 21
# Balanced: 84, 105
# All: 85, 128
# -----------
# Key: chr21	44692272	44711696
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 0, 0
# Balanced: 28, 17
# All: 29, 20
# -----------
# Key: chr21	42963134	42972049
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 4
# Balanced reference: 0, 0
# Balanced: 20, 20
# All: 27, 24
# -----------
# Key: chr21	44646315	44649629
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 0, 5
# Balanced: 18, 15
# All: 21, 22
# -----------
# Key: chr21	44664554	44676307
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 23, 20
# All: 23, 20
# -----------
# Key: chr21	32764667	32772612
# Unbalanced without reference: 0, 0
# Unbalanced: 16, 15
# Balanced reference: 0, 0
# Balanced: 68, 139
# All: 84, 154
# -----------
# Key: chr21	34510612	34524791
# Unbalanced without reference: 0, 0
# Unbalanced: 1,
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 0
# Balanced: 2, 16
# All: 2, 17
# -----------
# Key: chr21	44597399	44606933
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 0, 2
# All: 0, 2
# -----------
# Key: chr21	46176081	46185776
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 0, 4
# All: 0, 4
# -----------
# Key: chr21	33476897	33482312
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 0
# All: 1, 0
# -----------
# Key: chr22	36869942	36884190
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 8, 0
# Balanced: 61, 65
# All: 70, 67
# -----------
# Key: chr22	31749092	31754887
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 0
# Balanced reference: 6, 0
# Balanced: 72, 97
# All: 82, 97
# -----------
# Key: chr22	25197422	25213017
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 7
# Balanced reference: 3, 11
# Balanced: 64, 243
# All: 69, 261
# -----------
# Key: chr22	24551787	24556182
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 0
# Balanced reference: 2, 0
# Balanced: 48, 2
# All: 57, 2
# -----------
# Key: chr22	30464236	30472709
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 29
# Balanced: 95, 63
# All: 96, 92
# -----------
# Key: chr22	44358576	44367558
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 3, 24
# Balanced: 147, 91
# All: 151, 115
# -----------
# Key: chr22	46722068	46756948
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 6
# Balanced reference: 2, 20
# Balanced: 46, 40
# All: 54, 66
# -----------
# Key: chr22	41831545	41837054
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 1
# Balanced reference: 10, 0
# Balanced: 44, 66
# All: 59, 67
# -----------
# Key: chr22	25215681	25225395
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 23
# Balanced: 37, 92
# All: 38, 116
# -----------
# Key: chr22	27715693	27733804
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 9, 0
# Balanced: 162, 45
# All: 171, 45
# -----------
# Key: chr22	24945623	24946776
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 2
# Balanced reference: 2, 11
# Balanced: 30, 76
# All: 32, 89
# -----------
# Key: chr22	48810050	48815452
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 8
# Balanced reference: 0, 6
# Balanced: 60, 77
# All: 66, 91
# -----------
# Key: chr22	45149798	45167121
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 6
# Balanced reference: 0, 48
# Balanced: 82, 84
# All: 84, 138
# -----------
# Key: chr22	33918687	33923113
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 4
# Balanced reference: 21, 4
# Balanced: 216, 266
# All: 237, 274
# -----------
# Key: chr22	43810419	43819647
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 5, 5
# Balanced: 131, 87
# All: 136, 92
# -----------
# Key: chr22	29937145	29944828
# Unbalanced without reference: 0, 0
# Unbalanced: 16, 10
# Balanced reference: 3, 6
# Balanced: 87, 77
# All: 106, 93
# -----------
# Key: chr22	29554197	29562764
# Unbalanced without reference: 0, 0
# Unbalanced: 13, 4
# Balanced reference: 1, 0
# Balanced: 34, 73
# All: 48, 77
# -----------
# Key: chr22	36163149	36170042
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 6
# Balanced reference: 7, 0
# Balanced: 171, 65
# All: 185, 71
# -----------
# Key: chr22	22887340	22893245
# Unbalanced without reference: 0, 0
# Unbalanced: 19, 10
# Balanced reference: 1, 10
# Balanced: 74, 44
# All: 94, 64
# -----------
# Key: chr22	25731898	25746142
# Unbalanced without reference: 0, 0
# Unbalanced: 11, 0
# Balanced reference: 5, 0
# Balanced: 72, 40
# All: 88, 40
# -----------
# Key: chr22	31119465	31126318
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 0
# Balanced: 99, 61
# All: 100, 61
# -----------
# Key: chr22	37161957	37167826
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 10, 0
# Balanced: 111, 50
# All: 121, 51
# -----------
# Key: chr22	32782981	32789629
# Unbalanced without reference: 0, 0
# Unbalanced: 18, 4
# Balanced reference: 7, 0
# Balanced: 101, 63
# All: 126, 67
# -----------
# Key: chr22	31211806	31213394
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 2, 0
# Balanced: 89, 48
# All: 92, 51
# -----------
# Key: chr22	41919939	41934590
# Unbalanced without reference: 0, 0
# Unbalanced: 17, 3
# Balanced reference: 4, 0
# Balanced: 36, 45
# All: 57, 48
# -----------
# Key: chr22	38856369	38873147
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 5
# Balanced: 13, 19
# All: 14, 25
# -----------
# Key: chr22	38052575	38058131
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 22
# Balanced reference: 4, 1
# Balanced: 28, 103
# All: 34, 126
# -----------
# Key: chr22	50466499	50482637
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 7, 0
# Balanced: 25, 26
# All: 32, 26
# -----------
# Key: chr22	32041706	32050429
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 57
# Balanced: 59, 150
# All: 60, 207
# -----------
# Key: chr22	19704203	19722313
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 4
# Balanced reference: 4, 0
# Balanced: 75, 47
# All: 83, 51
# -----------
# Key: chr22	45406221	45417572
# Unbalanced without reference: 0, 0
# Unbalanced: 13, 12
# Balanced reference: 1, 22
# Balanced: 69, 66
# All: 83, 100
# -----------
# Key: chr22	29716809	29739971
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 0
# Balanced: 20, 36
# All: 21, 36
# -----------
# Key: chr22	48532180	48550780
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 2, 1
# Balanced: 104, 62
# All: 107, 64
# -----------
# Key: chr22	19722314	19741175
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 11
# Balanced: 16, 24
# All: 16, 35
# -----------
# Key: chr22	20855656	20865775
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 1
# Balanced reference: 8, 0
# Balanced: 56, 50
# All: 70, 51
# -----------
# Key: chr22	33320772	33327317
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 5
# Balanced reference: 1, 9
# Balanced: 61, 302
# All: 63, 316
# -----------
# Key: chr22	36911533	36914276
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 6, 0
# Balanced: 44, 42
# All: 50, 42
# -----------
# Key: chr22	50598032	50618927
# Unbalanced without reference: 0, 0
# Unbalanced: 9, 2
# Balanced reference: 4, 0
# Balanced: 26, 15
# All: 39, 17
# -----------
# Key: chr22	37281585	37293004
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 2, 3
# Balanced: 65, 35
# All: 67, 38
# -----------
# Key: chr22	40946044	40951950
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 1
# Balanced: 54, 36
# All: 55, 38
# -----------
# Key: chr22	28738821	28742811
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 8
# Balanced reference: 3, 0
# Balanced: 85, 75
# All: 98, 83
# -----------
# Key: chr22	33056536	33063370
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 2
# Balanced reference: 8, 0
# Balanced: 135, 132
# All: 145, 134
# -----------
# Key: chr22	25025563	25025809
# Unbalanced without reference: 0, 0
# Unbalanced: 12, 6
# Balanced reference: 3, 0
# Balanced: 43, 182
# All: 58, 188
# -----------
# Key: chr22	21631036	21633779
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 5, 0
# Balanced: 54, 75
# All: 59, 76
# -----------
# Key: chr22	37167827	37175536
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 9, 0
# Balanced: 107, 45
# All: 117, 46
# -----------
# Key: chr22	20494762	20504036
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 4
# Balanced reference: 1, 0
# Balanced: 52, 67
# All: 61, 71
# -----------
# Key: chr22	37658374	37668171
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 8
# Balanced reference: 3, 0
# Balanced: 20, 26
# All: 30, 34
# -----------
# Key: chr22	41993952	42006047
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 6
# Balanced reference: 2, 0
# Balanced: 8, 41
# All: 11, 47
# -----------
# Key: chr22	23069351	23083458
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 0
# Balanced reference: 5, 0
# Balanced: 119, 44
# All: 127, 44
# -----------
# Key: chr22	31942433	31946910
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 8, 1
# Balanced: 90, 144
# All: 98, 146
# -----------
# Key: chr22	31126319	31142025
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 0
# Balanced: 49, 38
# All: 50, 38
# -----------
# Key: chr22	17158523	17165407
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 4
# Balanced reference: 3, 0
# Balanced: 25, 80
# All: 31, 84
# -----------
# Key: chr22	44667726	44677886
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 1
# Balanced reference: 5, 0
# Balanced: 148, 41
# All: 160, 42
# -----------
# Key: chr22	40815762	40828839
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 5
# Balanced reference: 6, 0
# Balanced: 98, 51
# All: 104, 56
# -----------
# Key: chr22	30505161	30510631
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 8
# Balanced reference: 0, 0
# Balanced: 61, 62
# All: 68, 70
# -----------
# Key: chr22	39562440	39571667
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 2, 0
# Balanced: 47, 199
# All: 50, 199
# -----------
# Key: chr22	29133182	29135886
# Unbalanced without reference: 0, 0
# Unbalanced: 12, 7
# Balanced reference: 4, 0
# Balanced: 88, 24
# All: 104, 31
# -----------
# Key: chr22	36775350	36776391
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 10, 70
# Balanced: 116, 45
# All: 129, 117
# -----------
# Key: chr22	17358660	17367331
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 7, 28
# Balanced: 61, 84
# All: 69, 114
# -----------
# Key: chr22	31221007	31224446
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 3, 0
# Balanced: 119, 72
# All: 122, 72
# -----------
# Key: chr22	45930106	45983859
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 3
# ...
# Balanced: 38, 27
# All: 38, 27
# -----------
# Key: chr22	43273248	43276271
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 0, 0
# Balanced: 39, 156
# All: 41, 156
# -----------
# Key: chr22	39884563	39903077
# Unbalanced without reference: 0, 0
# Unbalanced: 13, 5
# Balanced reference: 0, 0
# Balanced: 76, 62
# All: 89, 67
# -----------
# Key: chr22	42647997	42653218
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 4
# Balanced reference: 0, 0
# Balanced: 35, 82
# All: 37, 86
# -----------
# Key: chr22	43408799	43417908
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 4
# Balanced reference: 2, 0
# Balanced: 43, 90
# All: 46, 94
# -----------
# Key: chr22	41687930	41690618
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 6
# Balanced reference: 1, 0
# Balanced: 58, 111
# All: 63, 117
# -----------
# Key: chr22	37222610	37248150
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 11, 3
# All: 11, 3
# -----------
# Key: chr22	23682065	23693628
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 1
# Balanced reference: 0, 17
# Balanced: 83, 46
# All: 86, 64
# -----------
# Key: chr22	50578974	50598031
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 1
# Balanced reference: 0, 0
# Balanced: 15, 20
# All: 17, 21
# -----------
# Key: chr22	38792249	38798749
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 17
# Balanced reference: 0, 0
# Balanced: 33, 45
# All: 38, 62
# -----------
# Key: chr22	45007067	45019239
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 1, 0
# Balanced: 30, 41
# All: 34, 43
# -----------
# Key: chr22	41677113	41687898
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 8
# Balanced reference: 0, 0
# Balanced: 17, 38
# All: 20, 46
# -----------
# Key: chr22	19141629	19145046
# Unbalanced without reference: 0, 0
# Unbalanced: 8, 31
# Balanced reference: 0, 0
# Balanced: 15, 98
# All: 23, 129
# -----------
# Key: chr22	39397894	39402353
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 11
# Balanced: 14, 6
# All: 14, 17
# -----------
# Key: chr22	36525583	36537051
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 10
# Balanced reference: 0, 0
# Balanced: 45, 92
# All: 46, 102
# -----------
# Key: chr22	41362854	41373372
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 0
# Balanced: 62, 48
# All: 63, 49
# -----------
# Key: chr22	20388957	20403343
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 11
# Balanced reference: 0, 0
# Balanced: 17, 39
# All: 19, 50
# -----------
# Key: chr22	26552559	26567235
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 0, 22
# Balanced: 39, 25
# All: 41, 47
# -----------
# Key: chr22	38837455	38846273
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 11
# Balanced reference: 0, 0
# Balanced: 29, 37
# All: 34, 48
# -----------
# Key: chr22	37008948	37020628
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 22, 9
# All: 22, 9
# -----------
# Key: chr22	37579976	37591245
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 2
# Balanced reference: 0, 0
# Balanced: 32, 15
# All: 36, 17
# -----------
# Key: chr22	38191282	38198422
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 3
# Balanced reference: 0, 0
# Balanced: 18, 19
# All: 21, 22
# -----------
# Key: chr22	30484599	30505160
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 2
# Balanced reference: 0, 1
# Balanced: 33, 10
# All: 38, 13
# -----------
# Key: chr22	36692575	36705326
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 1
# Balanced reference: 0, 0
# Balanced: 31, 56
# All: 35, 57
# -----------
# Key: chr22	37604182	37620566
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 0
# Balanced reference: 2, 0
# Balanced: 53, 34
# All: 58, 34
# -----------
# Key: chr22	17116729	17122470
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 27
# Balanced: 37, 78
# All: 37, 106
# -----------
# Key: chr22	20412904	20424609
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 4
# Balanced reference: 0, 0
# Balanced: 33, 53
# All: 33, 57
# -----------
# Key: chr22	38952241	38955105
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 1
# Balanced reference: 3, 0
# Balanced: 39, 32
# All: 45, 33
# -----------
# Key: chr22	38507631	38521653
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 2
# Balanced reference: 0, 0
# Balanced: 20, 17
# All: 21, 19
# -----------
# Key: chr22	20434852	20440860
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 0
# Balanced: 51, 65
# All: 52, 65
# -----------
# Key: chr22	26482969	26486725
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 18
# Balanced reference: 0, 0
# Balanced: 77, 86
# All: 83, 104
# -----------
# Key: chr22	37634107	37642542
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 6
# Balanced reference: 3, 0
# Balanced: 10, 20
# All: 15, 26
# -----------
# Key: chr22	29437418	29457649
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 10
# Balanced reference: 0, 18
# Balanced: 13, 24
# All: 18, 52
# -----------
# Key: chr22	38981457	38994168
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 1
# Balanced reference: 2, 0
# Balanced: 34, 11
# All: 38, 12
# -----------
# Key: chr22	45198213	45208816
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 0
# Balanced reference: 2, 1
# Balanced: 32, 61
# All: 37, 62
# -----------
# Key: chr22	50676680	50694482
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 3
# Balanced: 21, 3
# All: 22, 6
# -----------
# Key: chr22	38996564	39005552
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 3, 0
# Balanced: 49, 41
# All: 53, 44
# -----------
# Key: chr22	31451272	31457615
# Unbalanced without reference: 0, 0
# Unbalanced: 9, 25
# Balanced reference: 0, 0
# Balanced: 61, 55
# All: 70, 80
# -----------
# Key: chr22	50342334	50351441
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 0, 0
# Balanced: 6, 10
# All: 6, 13
# -----------
# Key: chr22	37674914	37688001
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 0
# Balanced: 13, 15
# All: 14, 16
# -----------
# Key: chr22	45237644	45246139
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 9
# Balanced reference: 4, 0
# Balanced: 28, 50
# All: 39, 59
# -----------
# Key: chr22	37696090	37717344
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 1
# Balanced reference: 1, 0
# Balanced: 9, 17
# All: 17, 18
# -----------
# Key: chr22	36787522	36820628
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 9
# Balanced: 60, 63
# All: 61, 73
# -----------
# Key: chr22	41373373	41378149
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 7
# Balanced reference: 0, 0
# Balanced: 27, 34
# All: 30, 41
# -----------
# Key: chr22	20262801	20283292
# Unbalanced without reference: 0, 0
# Unbalanced: 6, 4
# Balanced reference: 0, 1
# Balanced: 26, 9
# All: 32, 14
# -----------
# Key: chr22	45279193	45296792
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 1, 0
# Balanced: 42, 89
# All: 43, 89
# -----------
# Key: chr22	20003784	20020920
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 4
# Balanced reference: 0, 0
# Balanced: 12, 13
# All: 12, 17
# -----------
# Key: chr22	45299742	45311811
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 4
# Balanced reference: 0, 0
# Balanced: 42, 73
# All: 43, 77
# -----------
# Key: chr22	25968878	25988349
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 0
# Balanced: 44, 95
# All: 45, 96
# -----------
# Key: chr22	39094899	39106302
# Unbalanced without reference: 0, 0
# Unbalanced: 15, 6
# Balanced reference: 2, 0
# Balanced: 44, 32
# All: 61, 38
# -----------
# Key: chr22	31374708	31394252
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 1
# Balanced reference: 0, 0
# Balanced: 24, 12
# All: 28, 13
# -----------
# Key: chr22	21616007	21631035
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 2, 0
# Balanced: 37, 53
# All: 40, 53
# -----------
# Key: chr22	46064686	46076583
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 0
# Balanced reference: 0, 0
# Balanced: 47, 48
# All: 49, 48
# -----------
# Key: chr22	21633780	21642667
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 0
# Balanced reference: 3, 0
# Balanced: 6, 9
# All: 12, 9
# -----------
# Key: chr22	39143344	39181931
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 6
# Balanced reference: 0, 9
# Balanced: 40, 38
# All: 41, 53
# -----------
# Key: chr22	21651553	21653763
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 3, 0
# Balanced: 30, 53
# All: 34, 53
# -----------
# Key: chr22	23837323	23851365
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 18, 6
# All: 19, 6
# -----------
# Key: chr22	24247515	24271894
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 11
# Balanced reference: 0, 0
# Balanced: 35, 46
# All: 36, 57
# -----------
# Key: chr22	24464798	24477931
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 4
# Balanced reference: 0, 3
# Balanced: 34, 9
# All: 44, 16
# -----------
# Key: chr22	41698697	41704298
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 7
# Balanced reference: 0, 0
# Balanced: 20, 65
# All: 23, 72
# -----------
# Key: chr22	46149131	46160186
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 3
# Balanced reference: 0, 0
# Balanced: 43, 46
# All: 45, 49
# -----------
# Key: chr22	30324366	30328072
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 5
# Balanced reference: 0, 0
# Balanced: 19, 18
# All: 23, 23
# -----------
# Key: chr22	21735202	21760740
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 0
# Balanced: 24, 84
# All: 25, 85
# -----------
# Key: chr22	31063986	31067156
# Unbalanced without reference: 0, 0
# Unbalanced: 10, 1
# Balanced reference: 0, 0
# Balanced: 47, 34
# All: 57, 35
# -----------
# Key: chr22	43341947	43345157
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 6
# Balanced: 34, 40
# All: 35, 47
# -----------
# Key: chr22	31461033	31465692
# Unbalanced without reference: 0, 0
# Unbalanced: 9, 12
# Balanced reference: 0, 0
# Balanced: 45, 49
# All: 54, 61
# -----------
# Key: chr22	46295232	46306831
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 14, 1
# All: 14, 1
# -----------
# Key: chr22	29762431	29770475
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 5, 19
# All: 6, 19
# -----------
# Key: chr22	20999721	21005326
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 3
# Balanced reference: 0, 0
# Balanced: 24, 7
# All: 26, 10
# -----------
# Key: chr22	37212119	37222269
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 2, 0
# All: 2, 0
# -----------
# Key: chr22	46756949	46778428
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 1
# Balanced: 23, 51
# All: 23, 53
# -----------
# Key: chr22	26423700	26429489
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 3
# Balanced reference: 0, 0
# Balanced: 8, 27
# All: 9, 30
# -----------
# Key: chr22	31495046	31506628
# Unbalanced without reference: 0, 0
# Unbalanced: 4, 5
# Balanced reference: 0, 0
# Balanced: 18, 26
# All: 22, 31
# -----------
# Key: chr22	20083394	20096034
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 1
# Balanced reference: 0, 0
# Balanced: 15, 9
# All: 17, 10
# -----------
# Key: chr22	20111600	20116672
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 23, 15
# All: 23, 15
# -----------
# Key: chr22	20124106	20138526
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 32, 30
# All: 32, 30
# -----------
# Key: chr22	42612400	42624534
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 7
# Balanced reference: 0, 0
# Balanced: 4, 44
# All: 5, 51
# -----------
# Key: chr22	38700054	38704337
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 0
# Balanced reference: 0, 0
# Balanced: 11, 8
# All: 12, 8
# -----------
# Key: chr22	42640056	42647996
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 7
# Balanced reference: 0, 0
# Balanced: 14, 57
# All: 15, 64
# -----------
# Key: chr22	42570492	42585366
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 0, 4
# All: 0, 4
# -----------
# Key: chr22	21859515	21901350
# Unbalanced without reference: 0, 0
# Unbalanced: 7, 0
# Balanced reference: 0, 0
# Balanced: 16, 9
# All: 23, 9
# -----------
# Key: chr22	30629535	30650038
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 4, 31
# All: 4, 31
# -----------
# Key: chr22	42708721	42727439
# Unbalanced without reference: 0, 0
# Unbalanced: 5, 11
# Balanced reference: 0, 0
# Balanced: 21, 40
# All: 26, 51
# -----------
# Key: chr22	41445540	41453395
# Unbalanced without reference: 0, 0
# Unbalanced: 3, 2
# Balanced reference: 0, 0
# Balanced: 8, 22
# All: 11, 24
# -----------
# Key: chr22	23851366	23872408
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 12, 2
# All: 12, 2
# -----------
# Key: chr22	43993215	44001495
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 4
# Balanced reference: 0, 0
# Balanced: 6, 32
# All: 6, 36
# -----------
# Key: chr22	46111666	46122532
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 0, 0
# Balanced: 12, 25
# All: 12, 28
# -----------
# Key: chr22	19111150	19132339
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 16, 80
# All: 16, 80
# -----------
# Key: chr22	40526724	40528793
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 4
# All: 1, 4
# -----------
# Key: chr22	19146350	19158547
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 13
# Balanced reference: 0, 0
# Balanced: 16, 62
# All: 18, 75
# -----------
# Key: chr22	44169242	44184730
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 14, 2
# All: 14, 2
# -----------
# Key: chr22	19175210	19181611
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 21, 88
# All: 21, 88
# -----------
# Key: chr22	17004466	17011585
# Unbalanced without reference: 0, 0
# Unbalanced: 12, 5
# Balanced reference: 0, 0
# Balanced: 19, 18
# All: 31, 23
# -----------
# Key: chr22	22497779	22509530
# Unbalanced without reference: 0, 0
# Unbalanced: 1, 1
# Balanced reference: 0, 0
# Balanced: 6, 12
# All: 7, 13
# -----------
# Key: chr22	24166103	24201257
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 3
# Balanced reference: 0, 0
# Balanced: 28, 29
# All: 28, 32
# -----------
# Key: chr22	23616018	23632359
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 0
# Balanced: 2, 19
# All: 2, 20
# -----------
# Key: chr22	50535494	50555553
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 0
# Balanced: 5, 4
# All: 5, 5
# -----------
# Key: chr22	49820629	49854775
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 16, 29
# All: 16, 29
# -----------
# Key: chr22	36376731	36392587
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 0
# All: 1, 0
# -----------
# Key: chr22	45617630	45640103
# Unbalanced without reference: 0, 0
# Unbalanced: 2, 2
# Balanced reference: 0, 0
# Balanced: 5, 55
# All: 7, 57
# -----------
# Key: chr22	46566462	46582209
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 0, 3
# All: 0, 3
# -----------
# Key: chr22	20181708	20211956
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 1
# Balanced reference: 0, 0
# Balanced: 9, 7
# All: 9, 8
# -----------
# Key: chr22	39291810	39316268
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 4, 0
# All: 4, 0
# -----------
# Key: chr22	35378866	35401895
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 8, 9
# All: 8, 9
# -----------
# Key: chr22	50086141	50093274
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 3, 6
# All: 3, 6
# -----------
# Key: chr22	29896012	29899706
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 4, 15
# All: 4, 15
# -----------
# Key: chr22	50309117	50327992
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 4
# All: 1, 4
# -----------
# Key: chr22	37773859	37789508
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 0
# All: 1, 0
# -----------
# Key: chr22	36251563	36261418
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 1, 0
# All: 1, 0
# -----------
# Key: chr22	17078723	17092243
# Unbalanced without reference: 0, 0
# Unbalanced: 0, 0
# Balanced reference: 0, 0
# Balanced: 0, 13
# All: 0, 13
